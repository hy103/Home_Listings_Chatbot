# %%
import torch
import pandas as pd 
import numpy as np

# %%
from bs4 import BeautifulSoup
import requests

# %%
import requests

url = 'https://www.zillow.com/tempe-az/?searchQueryState=%7B%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22west%22%3A-112.04654735009765%2C%22east%22%3A-111.80965464990234%2C%22south%22%3A33.29486761692679%2C%22north%22%3A33.48892880892758%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A47958%2C%22regionType%22%3A6%7D%5D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A12%7D'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

response = requests.get(url, headers=headers)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
headings = soup.find_all('div')
for heading in headings:
    print(heading.text.strip())
# Out:
# Skip main navigationSign InJoin HomepageBuy Open Buy sub-menuRent Open Rent sub-menuSell Open Sell sub-menuHome Loans Open Home Loans sub-menuFind an Agent Open Find an Agent sub-menuManage Rentals Open Manage Rentals sub-menuAdvertise Help Sign InJoin
#
#
# ...

# %%
response
# Out:
# <Response [403]>
